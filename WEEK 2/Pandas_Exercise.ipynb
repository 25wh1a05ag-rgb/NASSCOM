# %%
import pandas as pd
import numpy as np

print("--- Intermediate Pandas Exercise ---")
print("Complete each task by writing the requested Pandas code.")
print("------------------------------------")

# Task 1: Basic Pandas Functions and Converting Arrays to DataFrames
print("\n--- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---")

# 1.1 Create a Pandas Series
s1_1 = pd.Series([10, 20, 30, 40, 50])

# 1.2 Create a 3x4 NumPy array with random integers
np_array1_2 = np.random.randint(1, 101, size=(3, 4))

# 1.3 Convert NumPy array into DataFrame
df1_3 = pd.DataFrame(np_array1_2, columns=['A', 'B', 'C', 'D'])

print(s1_1)
print(df1_3)


# Task 2: Synthetic Data Generation for Practice
print("\n--- Task 2: Synthetic Data Generation for Practice ---")

df_sales = pd.DataFrame({
    'Date': pd.date_range('2023-01-01', periods=100),
    'Region': np.random.choice(['East', 'West', 'North', 'South'], 100),
    'Product': np.random.choice(['Laptop', 'Mouse', 'Keyboard', 'Monitor'], 100),
    'Sales': np.random.randint(100, 1001, 100).astype(float),
    'Quantity': np.random.randint(1, 11, 100).astype(float)
})

# Introduce NaN values
sales_nan_idx = np.random.choice(df_sales.index, 5, replace=False)
quantity_nan_idx = np.random.choice(df_sales.index, 3, replace=False)

df_sales.loc[sales_nan_idx, 'Sales'] = np.nan
df_sales.loc[quantity_nan_idx, 'Quantity'] = np.nan

print(df_sales.head())


# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")

# 3.1 Select Region and Sales columns
df3_1 = df_sales[['Region', 'Sales']]

# 3.2 Select rows where Product is Laptop
df3_2 = df_sales[df_sales['Product'] == 'Laptop']

# 3.3 Select rows where Region is East and Sales > 500
df3_3 = df_sales[(df_sales['Region'] == 'East') & (df_sales['Sales'] > 500)]

# 3.4 Select Sales value for first Monitor entry
monitor_index = df_sales[df_sales['Product'] == 'Monitor'].index[0]
val3_4 = df_sales.loc[monitor_index, 'Sales']

# Alternative using iloc
# val3_4 = df_sales[df_sales['Product'] == 'Monitor'].iloc[0]['Sales']

print(df3_1.head())
print(df3_2.head())
print(df3_3.head())
print("First Monitor Sales:", val3_4)


# Task 4: Data Cleaning (Handling Missing Values)
print("\n--- Task 4: Data Cleaning (Handling Missing Values) ---")

# 4.1 Count missing values
missing_counts4_1 = df_sales.isna().sum()

# 4.2 Fill missing Sales with mean
df4_2_filled = df_sales.copy()
df4_2_filled['Sales'] = df4_2_filled['Sales'].fillna(df4_2_filled['Sales'].mean())

# 4.3 Drop rows with any missing values
df4_3_dropped = df_sales.dropna()

print(missing_counts4_1)
print(df4_2_filled.head())
print(df4_3_dropped.head())


# Task 5: Data Manipulation (Columns, Sorting, Grouping)
print("\n--- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---")

# 5.1 Create Total_Revenue column
df_sales['Total_Revenue'] = df_sales['Sales'] * df_sales['Quantity']

# 5.2 Sort by Date ascending and Sales descending
df5_2_sorted = df_sales.sort_values(by=['Date', 'Sales'], ascending=[True, False])

# 5.3 Group by Region and sum Sales and Quantity
df5_3_grouped_region = df_sales.groupby('Region')[['Sales', 'Quantity']].sum()

# 5.4 Group by Product and average Sales
df5_4_grouped_product = df_sales.groupby('Product')['Sales'].mean()

print(df5_2_sorted.head())
print("\nGrouped by Region:")
print(df5_3_grouped_region)

print("\nAverage Sales by Product:")
print(df5_4_grouped_product)
# Out:
# --- Intermediate Pandas Exercise ---
# Complete each task by writing the requested Pandas code.
# ------------------------------------
#
# --- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#     A   B    C   D
# 0   9  96   24  53
# 1  72  30  100  57
# 2  74  94   66  76
#
# --- Task 2: Synthetic Data Generation for Practice ---
#         Date Region   Product  Sales  Quantity
# 0 2023-01-01   East  Keyboard    NaN       9.0
# 1 2023-01-02   West   Monitor  624.0       4.0
# 2 2023-01-03  South     Mouse  303.0       5.0
# 3 2023-01-04  North    Laptop  157.0       5.0
# 4 2023-01-05  South  Keyboard  726.0       9.0
#
# --- Task 3: Indexing and Slicing in DataFrames ---
#   Region  Sales
# 0   East    NaN
# 1   West  624.0
# 2  South  303.0
# 3  North  157.0
# 4  South  726.0
#          Date Region Product  Sales  Quantity
# 3  2023-01-04  North  Laptop  157.0       5.0
# 10 2023-01-11   West  Laptop  238.0       7.0
# 14 2023-01-15  North  Laptop  796.0       7.0
# 19 2023-01-20  South  Laptop  430.0       5.0
# 25 2023-01-26  South  Laptop  198.0       7.0
#          Date Region   Product  Sales  Quantity
# 5  2023-01-06   East   Monitor  542.0       3.0
# 23 2023-01-24   East   Monitor  829.0       2.0
# 31 2023-02-01   East    Laptop  536.0       6.0
# 34 2023-02-04   East  Keyboard  714.0       6.0
# 49 2023-02-19   East   Monitor  909.0       4.0
# First Monitor Sales: 624.0
#
# --- Task 4: Data Cleaning (Handling Missing Values) ---
# Date        0
# Region      0
# Product     0
# Sales       5
# Quantity    3
# dtype: int64
#         Date Region   Product       Sales  Quantity
# 0 2023-01-01   East  Keyboard  542.673684       9.0
# 1 2023-01-02   West   Monitor  624.000000       4.0
# 2 2023-01-03  South     Mouse  303.000000       5.0
# 3 2023-01-04  North    Laptop  157.000000       5.0
# 4 2023-01-05  South  Keyboard  726.000000       9.0
#         Date Region   Product  Sales  Quantity
# 1 2023-01-02   West   Monitor  624.0       4.0
# 2 2023-01-03  South     Mouse  303.0       5.0
# 3 2023-01-04  North    Laptop  157.0       5.0
# 4 2023-01-05  South  Keyboard  726.0       9.0
# 5 2023-01-06   East   Monitor  542.0       3.0
#
# --- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---
#         Date Region   Product  Sales  Quantity  Total_Revenue
# 0 2023-01-01   East  Keyboard    NaN       9.0            NaN
# 1 2023-01-02   West   Monitor  624.0       4.0         2496.0
# 2 2023-01-03  South     Mouse  303.0       5.0         1515.0
# 3 2023-01-04  North    Laptop  157.0       5.0          785.0
# 4 2023-01-05  South  Keyboard  726.0       9.0         6534.0
#
# Grouped by Region:
#           Sales  Quantity
# Region
# East     9138.0     122.0
# North   15662.0     144.0
# South    9833.0     101.0
# West    16921.0     202.0
#
# Average Sales by Product:
# Product
# Keyboard    504.611111
# Laptop      484.137931
# Monitor     601.304348
# Mouse       584.040000
# Name: Sales, dtype: float64
