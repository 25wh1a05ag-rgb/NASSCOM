# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),   # Celsius
    'Humidity_Sensor': (30.0, 80.0),      # Percentage
    'Pressure_Sensor': (980.0, 1030.0),   # hPa
    'Light_Sensor': (100, 1000)           # Lux
}

# ---------------------------------------------------------------------
# Task 1: Python Fundamentals
# ---------------------------------------------------------------------
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate 100 simulated sensor readings
raw_sensor_data = []

start_time = datetime.datetime.now()

for i in range(100):
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    min_value, max_value = READING_RANGES[device_type]
    value = round(random.uniform(min_value, max_value), 2)

    timestamp = (start_time + datetime.timedelta(minutes=i)).strftime(
        "%Y-%m-%d %H:%M:%S"
    )

    device_id = f"DEV{i+1:03d}"

    raw_sensor_data.append(
        (timestamp, device_id, device_type, location, value)
    )

print(f"Generated {len(raw_sensor_data)} sensor readings.")

# ---------------------------------------------------------------------
# 1.2 Temperature readings list of dictionaries
# ---------------------------------------------------------------------
temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": reading[0],
            "device_id": reading[1],
            "location": reading[3],
            "temperature_celsius": reading[4]
        })

print("Temperature readings:", len(temperature_readings))

# ---------------------------------------------------------------------
# 1.3 Unique locations
# ---------------------------------------------------------------------
unique_locations = {reading[3] for reading in raw_sensor_data}

print("Unique Locations:")
print(unique_locations)

# ---------------------------------------------------------------------
# 1.4 Device statistics
# ---------------------------------------------------------------------
device_stats = {}

for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))

for reading in raw_sensor_data:
    device = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device]

    device_stats[device] = (
        min(current_min, value),
        max(current_max, value)
    )

print("\nDevice Statistics")
for device, stats in device_stats.items():
    print(device, stats)

# ---------------------------------------------------------------------
# 1.5 Indexing & Slicing
# ---------------------------------------------------------------------
print("\n--- Task 1.5: Advanced Indexing and Slicing ---")

sample_string = "PythonProgrammingIsFun"

# 1.5.1
sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]

print("10th-20th readings:", len(sliced_readings_1))
print("Every 5th reading:", len(sliced_readings_2))

# 1.5.2
substring_1 = sample_string[6:17]
substring_2 = sample_string[:6][::-1]

print("Substring 1:", substring_1)
print("Substring 2:", substring_2)

# 1.5.3
fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6:]

print("5th Device Type:", fifth_reading_device_type)
print("Suffix:", device_type_suffix)

# ---------------------------------------------------------------------
# Task 2: Functions
# ---------------------------------------------------------------------
print("\n--- Task 2: Function Definitions and Usage ---")


def get_readings_by_location(readings_list, target_location):
    """Return all readings from the target location."""
    return [
        reading
        for reading in readings_list
        if reading[3] == target_location
    ]


def calculate_average_temperature(temp_data_list):
    """Return average temperature."""
    if not temp_data_list:
        return 0.0

    total = sum(
        reading["temperature_celsius"]
        for reading in temp_data_list
    )

    return total / len(temp_data_list)


def generate_report_line(reading_dict):
    """Generate formatted report line."""
    return (
        f"[{reading_dict['timestamp']}] "
        f"Device {reading_dict['device_id']} "
        f"at {reading_dict['location']}: "
        f"{reading_dict['temperature_celsius']}°C"
    )


# Function Testing
lab1_readings = get_readings_by_location(raw_sensor_data, "Lab1")
print("Lab1 readings:", len(lab1_readings))

average_temp = calculate_average_temperature(temperature_readings)
print(f"Average Temperature: {average_temp:.2f}°C")

if temperature_readings:
    print(generate_report_line(temperature_readings[0]))

# ---------------------------------------------------------------------
# Task 3: Core Libraries
# ---------------------------------------------------------------------
print("\n--- Task 3: Core Library Usage ---")

# 3.1 Create directory
reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")
else:
    print(f"Directory '{reports_dir}' already exists.")

# ---------------------------------------------------------------------
# 3.2 Duration
# ---------------------------------------------------------------------
if len(raw_sensor_data) > 1:

    first_timestamp = raw_sensor_data[0][0]
    last_timestamp = raw_sensor_data[-1][0]

    date_format = "%Y-%m-%d %H:%M:%S"

    first_dt = datetime.datetime.strptime(first_timestamp, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp, date_format)

    duration = last_dt - first_dt

    days = duration.days
    hours = duration.seconds // 3600
    minutes = (duration.seconds % 3600) // 60

    print(
        f"Duration: {days} days, {hours} hours, {minutes} minutes"
    )

# ---------------------------------------------------------------------
# 3.3 Random values
# ---------------------------------------------------------------------
random_values = [random.randint(100, 200) for _ in range(5)]

print("Random Values:", random_values)

# ---------------------------------------------------------------------
# Task 4: File Handling
# ---------------------------------------------------------------------
print("\n--- Task 4: File I/O ---")

report_filename = os.path.join(
    reports_dir,
    "temperature_report.txt"
)

# 4.1 Write report
try:
    with open(report_filename, "w") as file:
        for reading in temperature_readings:
            file.write(generate_report_line(reading) + "\n")

    print("Temperature report written successfully.")

except IOError as e:
    print("File Write Error:", e)

# ---------------------------------------------------------------------
# 4.2 Read report
# ---------------------------------------------------------------------
read_report_lines = []

try:
    with open(report_filename, "r") as file:
        read_report_lines = file.readlines()

    print("\nFirst 3 Lines of Report:")

    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print("File Read Error:", e)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# Generated 100 sensor readings.
# Temperature readings: 28
# Unique Locations:
# {'Lab2', 'Warehouse', 'Lab1', 'OfficeB', 'OfficeA'}
#
# Device Statistics
# Temperature_Sensor (18.43, 30.0)
# Humidity_Sensor (30.75, 79.92)
# Pressure_Sensor (980.42, 1025.47)
# Light_Sensor (100.82, 942.33)
#
# --- Task 1.5: Advanced Indexing and Slicing ---
# 10th-20th readings: 11
# Every 5th reading: 20
# Substring 1: Programming
# Substring 2: nohtyP
# 5th Device Type: Light_Sensor
# Suffix: Sensor
#
# --- Task 2: Function Definitions and Usage ---
# Lab1 readings: 17
# Average Temperature: 23.52°C
# [2026-07-30 09:19:25] Device DEV006 at OfficeA: 22.65°C
#
# --- Task 3: Core Library Usage ---
# Directory 'sensor_reports' created.
# Duration: 0 days, 1 hours, 39 minutes
# Random Values: [101, 120, 111, 196, 108]
#
# --- Task 4: File I/O ---
# Temperature report written successfully.
#
# First 3 Lines of Report:
# [2026-07-30 09:19:25] Device DEV006 at OfficeA: 22.65°C
# [2026-07-30 09:22:25] Device DEV009 at OfficeA: 29.86°C
# [2026-07-30 09:24:25] Device DEV011 at Lab2: 19.91°C
#
# --- Exercise Complete! ---
# Total Sensor Readings: 100
# Temperature Readings: 28
# Average Temperature: 23.52°C
# Unique Locations: {'Lab2', 'Warehouse', 'Lab1', 'OfficeB', 'OfficeA'}
# Random Values: [101, 120, 111, 196, 108]
#
# Great job completing the intermediate Python exercise!
